# %% [markdown]
# # 1.Import necessary packages

# %%
import numpy as py
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# # 2.Load the file

# %%
data = pd.read_csv('Inc_Exp_Data.csv')

# %% [markdown]
# # 3.Analyze the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
data.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %% [markdown]
# # 4.What is the Mean Expense of a Household?
#
# $18,818.00

# %%
data['Mthly_HH_Expense'].mean()
# Out:
# 18818.0

# %% [markdown]
# # 5.What is the Median Household Expense?
#
# $15,500.00

# %%
data['Mthly_HH_Expense'].median()
# Out:
# 15500.0

# %% [markdown]
# # 6.What is the Monthly Expense for most of the Households?
#
# $25,000.00

# %%
data['Mthly_HH_Expense'].mode()
# Out:
# 0    25000
# dtype: int64

# %% [markdown]
# # 7.Plot the Histogram to count the Highest qualified member

# %%
# %matplotlib inline

data.hist(figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcb08acc3a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcb291446a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcb29171b20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcb48116f70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcb48566400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcb48593790>]],
#       dtype=object)

# %% [markdown]
# # 8.Calculate IQR(difference between 75% and 25% quartile)

# %%
data.describe(include="all")
# Out:
#         Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count         50.000000         50.000000          50.000000        50.000000
# unique              NaN               NaN                NaN              NaN
# top                 NaN               NaN                NaN              NaN
# freq                NaN               NaN                NaN              NaN
# mean       41558.000000      18818.000000           4.060000      3060.000000
# std        26097.908979      12090.216824           1.517382      6241.434948
# min         5000.000000       2000.000000           1.000000         0.000000
# 25%        23550.000000      10000.000000           3.000000         0.000000
# 50%        35000.000000      15500.000000           4.000000         0.000000
# 75%        50375.000000      25000.000000           5.000000      3500.000000
# max       100000.000000      50000.000000           7.000000     35000.000000
#
#         Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# count       5.000000e+01                       50              50.000000
# unique               NaN                        5                    NaN
# top                  NaN                 Graduate                    NaN
# freq                 NaN                       19                    NaN
# mean        4.900190e+05                      NaN               1.460000
# std         3.201358e+05                      NaN               0.734291
# min         6.420000e+04                      NaN               1.000000
# 25%         2.587500e+05                      NaN               1.000000
# 50%         4.474200e+05                      NaN               1.000000
# 75%         5.947200e+05                      NaN               2.000000
# max         1.404000e+06                      NaN               4.000000

# %% [markdown]
# Income IQR  = (50375-23550) = 26,825
#
# Expense IQR = (25000-10000) = 15,000

# %% [markdown]
# # 9.Calculate Standard Deviation for first 4 columns.

# %% [markdown]
# Income: 26,097.91
#
# Expense: 12,090.22
#
# Fly Members: 1.52
#
# Rent: 6,241.43

# %% [markdown]
# # 10.Calculate Variance for first 3 columns.

# %%
py.var(data)
# Out:
# Mthly_HH_Income          6.674788e+08
# Mthly_HH_Expense         1.432499e+08
# No_of_Fly_Members        2.256400e+00
# Emi_or_Rent_Amt          3.817640e+07
# Annual_HH_Income         1.004372e+11
# No_of_Earning_Members    5.284000e-01
# dtype: float64

# %% [markdown]
# # 11.Calculate the count of Highest qualified member.

# %%
# Qualified is not defined so it's hard to know what they mean

data.describe()

# If qualified = No_of_Fly_Members then 7, if earning then 4
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# 25%        2.587500e+05               1.000000
# 50%        4.474200e+05               1.000000
# 75%        5.947200e+05               2.000000
# max        1.404000e+06               4.000000

# %% [markdown]
# # 12.Plot the Histogram to count the No_of_Earning_Members

# %%
data['No_of_Earning_Members'].hist()

# %% [markdown]
# # 13.Suppose you have option to invest in Stock A or Stock B. The stocks • have different expected returns and standard deviations. The expected return of Stock A is 15% and Stock B is 10%. Standard Deviation of the returns of these stocks is 10% and 5% respectively.
#
# Which is better investment?

# %%
# A - 15% ± 10%
# B - 10% ±  5%

# A can give higher returns but carries more risk
# B is less risky but has a lower maximum return
